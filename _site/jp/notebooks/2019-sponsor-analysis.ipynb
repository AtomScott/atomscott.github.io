# %% [markdown]
# # スポンサー分析

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
xlsx_path = '/home/atom/Documents/football_data.xlsx'
sheets = pd.read_excel(xlsx_path, sheet_name=None)
sheets.keys()
# Out:
# odict_keys(['Global sponsorship spending', 'JLeague Sponsor Revenue', 'Premier League Sponsors', 'J League Sponsors'])

# %%
from IPython.core.display import display

PL_sponsors = sheets['Premier League Sponsors'].drop(0)
JL_sponsors = sheets['J League Sponsors'].drop(0)
display(PL_sponsors.head(3))
display(JL_sponsors.head(3))
# Out:
#    Unnamed: 0 Liverpool Leicester City Chelsea Man. City Sheff Utd Arsenal  \
# 1      1979.0   Hitachi            NaN     NaN       NaN  Cantor's     NaN
# 2      1980.0   Hitachi            NaN     NaN       NaN  Cantor's     NaN
# 3      1981.0   Hitachi            NaN     NaN       NaN  Bentleys     NaN
#
#      Bournemouth                    Brighton Burnley  ...  \
# 1            NaN                         NaN     NaN  ...
# 2  Heynes Toyota  British Caledonian Airways     NaN  ...
# 3  Heynes Toyota  British Caledonian Airways     NaN  ...
#
#              Newcastle Tottenham Everton Man United Wolves West Ham  \
# 1                  NaN       NaN  Hafnia        NaN    NaN      NaN
# 2  Newcastle Brown Ale       NaN  Hafnia        NaN    NaN      NaN
# 3  Newcastle Brown Ale       NaN  Hafnia        NaN    NaN      NaN
#
#   Aston Villa Watford Southampton Norwich
# 1         NaN     NaN         NaN     NaN
# 2         NaN     NaN  Rank Xeroz     NaN
# ...

# %%
import urllib.request
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/1999%E2%80%932000_FA_Premier_League"
page = urllib.request.urlopen(url)

soup = BeautifulSoup(page, "lxml")
right_table=soup.find('table', class_='wikitable sortable')

# %%
ff
